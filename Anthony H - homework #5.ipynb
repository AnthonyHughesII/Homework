# %% [markdown]
# # Anthony Hughes II
# ## Homework #5
# ### Nov. 9, 2025
#
# 1. Pandas stands for either 'Panel Date' or 'Python Data Analysis'
# 1. Series and DataFrames
# 1. manipulate, prepare, model, and analyze
# 1. inplace
# 1. a data file
# 1.
