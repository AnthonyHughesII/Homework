# %% [markdown]
# <!-- Headings -->
# # Anthony Hughes II
# <!-- Italics -->
# ## *Homework #3*
#
# <!-- OL -->
# 1. An algorithm is a series of steps to solve a problem at hand.
# 1. Variables may not start with a special character or  a number.
# 1. Semantic errors is when the code is grammatically correct but results don't make any sense; it does not produce the expected results.
# 1. Complexity is the enemy of efficiency
# 1. print, if, else, return, true

# %%
aboutMe = """Anthony,
Sweet Potatoes,
and a Programmer
"""
print(aboutMe)

#Variable Naming
program = "Savvy Coders"
duration = 10
list; skills = "data analysis", "python", "SQL", "agile"
bool; decision = True
tuple; games = """NBA 2K
FIFA
NHL
Call of Duty"""

print("My string is:", program)
print("The length of the string is", len(program))
print(program[5])
print("The index value of the 4th character is 5:", program[5])

savvy = "\n\nLearning Data Analytics and Python is Awesome"
print(savvy)
print("The string after being sliced is:", savvy[5:24])
print("The string after 'Awesome' is replaced:", savvy.replace("Awesome", "Great"))

if "Python" in savvy:
    print("\nYes, Python is found.")
else: 
    print("Python was not found.")

print("\n")


name, age, height = "John Smith", 30, 70

miniBio = "Hi, my name is {name}, I am {tall} inches tall and {so} years old.".format(name=name, tall=height, so=age)
print(name, age, height)
print(miniBio)


#complex data types
#list
print("\n")
games = ["NBA", "FIFA", "COD", "NHL", "GTA"]
print("I created a list, games:", (games))
print("There are", len(games), "items in the list")
games[3] = "placeholder"
print("4th game is replaced...", games)
games.append("NFL")
games.append("MLB")
print("\nNew list length:", (len(games)), "\n")

newGameList = games[2:6]
print("2nd List:", newGameList, "\n")
games.extend(newGameList)
print("Extended orginal list:", games, "\n")

simList = [5, 17, 25, 7, 12]
print("There is NOW a list of integers:", simList)
simList.sort()
print("Sorted List:", simList)
thirdList = simList.copy()
combineList = newGameList + thirdList
print("Combined 2nd & 3rd List:", combineList, "\n\n")


#tuples
orginalTup = 'anthony', 'twenty six', 'python', 'basketball', 'savvy coders'
print("I created a tuple:", orginalTup)
tuple2 = orginalTup * 3
print("12th element of 2nd tuple:", tuple2[12])
print("Sorted Tuple:", sorted(tuple2))
tuple3 = (tuple2[0], tuple2[2], tuple2[4], tuple2[-1])
myName, language, education, education2 = tuple3
print("3rd Tuple:", myName, language, education, education2)
tuple4 = 50,
print("4th Tuple:", tuple4)
tuple5 = tuple2 + tuple3; print("5th Tuple:", tuple5, "\n")


#sets
mocha = {"nia", "ari", "simone"}; print("set:", mocha)
fruitList = ["pineapple", "watermelon", "apples"]
mocha.update(fruitList); print("Updated Set:", mocha)
mocha.add("jaguar")
random = {"starburst", "goldendoodle", "keyboard"}
united = mocha.union(random); print("United Sets:", united)
random.pop(); print("Remainder of 2nd set:", random)
mocha.clear(); print("1st set cleared:", mocha)
united.discard("apples"); united.remove("keyboard"); print("Remainder of 3rd set:", united)


#dictionary
bio = {
    "name": "John Doe",
    "licenseNumber": "Y123456789",
    "age": 26,
    "accidentRecord": False,
    "carType": ["compact", "sedan", "suv", "truck"]
}
print("One value of this Dict:", bio["licenseNumber"])
bio["name"] = "anthony"; bio["color"] = "blue"
practiceTup = 'showTypes'
bio[practiceTup] = 'anime', 'sitcom', 'horror'
print("List of dictionary keys:", list(bio.keys()))
print("List of dictionary values:", list(bio.values()))
import copy
newBio = copy.deepcopy(bio)
newBio.pop("age"); print("Dictionary after pop:", newBio)
newBio.clear(); print("All elements removed:", newBio)
# Out:
# Anthony,
# Sweet Potatoes,
# and a Programmer
#
# My string is: Savvy Coders
# The length of the string is 12
#
# The index value of the 4th character is 5:
#
#
# Learning Data Analytics and Python is Awesome
# The string after being sliced is: rning Data Analytic
# The string after 'Awesome' is replaced:
#
# Learning Data Analytics and Python is Great
#
# Yes, Python is found.
#
#
# John Smith 30 70
# Hi, my name is John Smith, I am 70 inches tall and 30 years old.
#
#
# I created a list, games: ['NBA', 'FIFA', 'COD', 'NHL', 'GTA']
# There are 5 items in the list
# 4th game is replaced... ['NBA', 'FIFA', 'COD', 'placeholder', 'GTA']
#
# New list length: 7
#
# 2nd List: ['COD', 'placeholder', 'GTA', 'NFL']
#
# Extended orginal list: ['NBA', 'FIFA', 'COD', 'placeholder', 'GTA', 'NFL', 'MLB', 'COD', 'placeholder', 'GTA', 'NFL']
#
# There is NOW a list of integers: [5, 17, 25, 7, 12]
# Sorted List: [5, 7, 12, 17, 25]
# ...
